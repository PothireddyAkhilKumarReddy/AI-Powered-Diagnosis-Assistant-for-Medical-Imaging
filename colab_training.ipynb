# %% [markdown]
# # 🏥 Medical AI Bot Training on Colab
#
# Use this notebook to train your model on Google's powerful GPUs for free!
#
# **Model Architecture:** EfficientNetB0 (Smaller, faster, and more accurate than ResNet50)

# %%
# Step 1: Check GPU
# !nvidia-smi

# %%
# Step 2: Mount Google Drive (Optional - if you uploaded zip to Drive)
from google.colab import drive
drive.mount('/content/drive')

# %%
# Step 3: Unzip your project
# ⚠️ Upload your 'backend.zip' to the sidebar files or use Drive path
# !unzip -q backend.zip -d project_data

# %%
# Step 4: Setup Workspace (Using Robust Paths)
import os

# 1. Find the correct directory
if os.path.exists('project_data/backend'):
    # %cd project_data/backend
else:
    # %cd project_data

print(f"Current working directory: {os.getcwd()}")

# 2. No need for pip install (Colab has everything pre-installed!)

# %%
# Step 5: Train the Model 🚀
# (This uses the combined dataset. Make sure you included the images in the zip!)
# 💡 Using EfficientNetB0 --model_type efficientnet for better efficiency and smaller file size (~20MB)
# !python train_model.py --dataset combined --epochs 20 --model_type efficientnet

# %%
# Step 6: Download the Trained Model
from google.colab import files
files.download('model.h5')
files.download('training_history.png')
